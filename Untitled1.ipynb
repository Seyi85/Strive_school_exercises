# %%
# !pip install requests

# %%
# !pip install BeautifulSoup4

# %%
import requests
from bs4 import BeautifulSoup

page =requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7771&lon=-122.4196&unit=0&lg=english&FcstType=text&TextType=2")
#print the status of the response.

soup =BeautifulSoup(page.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html public "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html>
#  <head>
#   <style>
#    body {
#   font-family: Arial !important;
# }
# ul{
#     list-style-type: none;
# }
# .point-forecast-7-day{
#     margin-left:-40px;
# }
# .warn{
#     color: #FF0000;
#     font-weight:bold;
#     text-decoration: underline;
# }
# li.forecast-tombstone + li {
#     margin-left: 12px;
# }
# li.forecast-tombstone,
# li.forecast-tombstone > div {
#     display: inline-block;
# }
# li.forecast-tombstone img {
#     margin: auto;
#     width: 55px;
#     height: 58px;
# }
# li.forecast-tombstone p {
#     text-align: center;
#     font-size: 12px !important;
# }
# .txt-ctr-caps {
#     font-weight: bold;
# }
#   </style>
#   <title>
#    7-Day Forecast for Latitude 37.77°N and Longitude 122.41°W (Elev. 131 ft) (Text-Only)
#   </title>
#  </head>
#  <body bgcolor="#FFFFFF" leftmargin="0" marginheight="0" marginwidth="0" rightmargin="0" text="#000000" topmargin="0">
# ...

# %%
b = list(body.children)[1]

b = soup.find("b")

print(b)
# Out:
# <b>NWS Forecast for: San Francisco CA</b>

# %%
soup.find_all("p")
# Out:
# [<p class="txt-ctr-caps">Today<br/><br/></p>,
#  <p><img alt="Today: Mostly sunny, with a high near 61. West wind 7 to 17 mph, with gusts as high as 22 mph. " class="forecast-icon" src="newimages/medium/sct.png" title="Today: Mostly sunny, with a high near 61. West wind 7 to 17 mph, with gusts as high as 22 mph. "/></p>,
#  <p class="txt-dual">Mostly Sunny<br/><br/><br/></p>,
#  <p class="point-forecast-icons-high">High: 61 °F</p>,
#  <p class="txt-ctr-caps">Tonight<br/><br/></p>,
#  <p><img alt="Tonight: Partly cloudy, with a low around 47. West northwest wind 9 to 14 mph becoming light north northwest  after midnight. Winds could gust as high as 18 mph. " class="forecast-icon" src="newimages/medium/nsct.png" title="Tonight: Partly cloudy, with a low around 47. West northwest wind 9 to 14 mph becoming light north northwest  after midnight. Winds could gust as high as 18 mph. "/></p>,
#  <p class="txt-dual">Partly Cloudy<br/><br/><br/></p>,
# ...

# %%
for p in soup.find_all("p"):
    
    print(p.text)
    
    print("-----")
# Out:
# Today
# -----
#
# -----
# Mostly Sunny
# -----
# High: 61 °F
# -----
# Tonight
# -----
#
# -----
# Partly Cloudy
# -----
# Low: 47 °F
# -----
# Friday
# -----
#
# -----
# Mostly Sunny
# -----
# High: 58 °F
# -----
# FridayNight
# -----
#
# -----
# Chance Rain
# -----
# Low: 51 °F
# -----
# Saturday
# -----
#
# -----
# Chance Rain
# -----
# High: 60 °F
# -----
# SaturdayNight
# -----
#
# -----
# Chance Rain
# -----
# Low: 52 °F
# -----
# Sunday
# -----
#
# -----
# Rain Likely
# -----
# High: 61 °F
# -----
# SundayNight
# -----
#
# -----
# Chance Rainthen MostlyCloudy
# -----
# Low: 49 °F
# -----
# Monday
# -----
#
# -----
# Partly Sunny
# -----
# High: 60 °F
# -----

# %%
soup.find(class_="forecast-tombstone")
# Out:
# <li class="forecast-tombstone"><div><p class="txt-ctr-caps">This<br/>Afternoon</p>
# <p><img alt="This Afternoon: Mostly sunny, with a high near 61. West wind 13 to 17 mph, with gusts as high as 22 mph. " class="forecast-icon" src="newimages/medium/sct.png" title="This Afternoon: Mostly sunny, with a high near 61. West wind 13 to 17 mph, with gusts as high as 22 mph. "/></p><p class="txt-dual">Mostly Sunny<br/><br/><br/></p><p class="point-forecast-icons-high">High: 61 °F</p></div></li>

# %%
# Out:
# []
